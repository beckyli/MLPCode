# %% [markdown]
# ## mahotas
# 是计算机视觉和图像处理 Python 库

# %%
import mahotas as mh
import cv2
from matplotlib import pyplot as plt


image = cv2.imread("scene00.jpg")
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
plt.imshow(gray)

# %%
plt.imshow(image)

# %%
thresh =
